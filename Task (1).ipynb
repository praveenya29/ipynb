# %%
import pandas

# %%
import pandas as pd
df=pd.read_csv("https://raw.githubusercontent.com/AP-State-Skill-Development-Corporation/Datasets/master/Data%20Analysis/Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.head()
# Out:
#    Unnamed: 0     TV  radio  newspaper  sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df['TV'].unique()
# Out:
# array([230.1,  44.5,  17.2, 151.5, 180.8,   8.7,  57.5, 120.2,   8.6,
#        199.8,  66.1, 214.7,  23.8,  97.5, 204.1, 195.4,  67.8, 281.4,
#         69.2, 147.3, 218.4, 237.4,  13.2, 228.3,  62.3, 262.9, 142.9,
#        240.1, 248.8,  70.6, 292.9, 112.9,  97.2, 265.6,  95.7, 290.7,
#        266.9,  74.7,  43.1, 228. , 202.5, 177. , 293.6, 206.9,  25.1,
#        175.1,  89.7, 239.9, 227.2,  66.9, 100.4, 216.4, 182.6, 262.7,
#        198.9,   7.3, 136.2, 210.8, 210.7,  53.5, 261.3, 239.3, 102.7,
#        131.1,  69. ,  31.5, 139.3, 216.8, 199.1, 109.8,  26.8, 129.4,
#        213.4,  16.9,  27.5, 120.5,   5.4, 116. ,  76.4, 239.8,  75.3,
#         68.4, 213.5, 193.2,  76.3, 110.7,  88.3, 134.3,  28.6, 217.7,
#        250.9, 107.4, 163.3, 197.6, 184.9, 289.7, 135.2, 222.4, 296.4,
#        280.2, 187.9, 238.2, 137.9,  25. ,  90.4,  13.1, 255.4, 225.8,
#        241.7, 175.7, 209.6,  78.2,  75.1, 139.2, 125.7,  19.4, 141.3,
# ...

# %%
df['newspaper'].unique()
# Out:
# array([ 69.2,  45.1,  69.3,  58.5,  58.4,  75. ,  23.5,  11.6,   1. ,
#         21.2,  24.2,   4. ,  65.9,   7.2,  46. ,  52.9, 114. ,  55.8,
#         18.3,  19.1,  53.4,  49.6,  26.2,  19.5,  12.6,  22.9,  40.8,
#         43.2,  38.6,  30. ,   0.3,   7.4,   8.5,   5. ,  45.7,  35.1,
#         32. ,  31.6,  38.7,   1.8,  26.4,  43.3,  31.5,  35.7,  18.5,
#         49.9,  36.8,  34.6,   3.6,  39.6,  58.7,  15.9,  60. ,  41.4,
#         16.6,  37.7,   9.3,  21.4,  54.7,  27.3,   8.4,  28.9,   0.9,
#          2.2,  10.2,  11. ,  27.2,  31.7,  19.3,  31.3,  13.1,  89.4,
#         20.7,  14.2,   9.4,  23.1,  22.3,  36.9,  32.5,  35.6,  33.8,
#         65.7,  16. ,  63.2,  73.4,  51.4,  33. ,  59. ,  72.3,  10.9,
#          5.9,  22. ,  51.2,  45.9,  49.8, 100.9,  17.9,   5.3,  29.7,
#         23.2,  25.6,   5.5,  56.5,   2.4,  10.7,  34.5,  52.7,  14.8,
#         79.2,  46.2,  50.4,  15.6,  12.4,  74.2,  25.9,  50.6,   9.2,
# ...

# %%
df['radio'].unique()
# Out:
# array([37.8, 39.3, 45.9, 41.3, 10.8, 48.9, 32.8, 19.6,  2.1,  2.6,  5.8,
#        24. , 35.1,  7.6, 32.9, 47.7, 36.6, 39.6, 20.5, 23.9, 27.7,  5.1,
#        15.9, 16.9, 12.6,  3.5, 29.3, 16.7, 27.1, 16. , 28.3, 17.4,  1.5,
#        20. ,  1.4,  4.1, 43.8, 49.4, 26.7, 37.7, 22.3, 33.4,  8.4, 25.7,
#        22.5,  9.9, 41.5, 15.8, 11.7,  3.1,  9.6, 41.7, 46.2, 28.8, 28.1,
#        19.2, 49.6, 29.5,  2. , 42.7, 15.5, 29.6, 42.8,  9.3, 24.6, 14.5,
#        27.5, 43.9, 30.6, 14.3, 33. ,  5.7, 43.7,  1.6, 28.5, 29.9,  7.7,
#        20.3, 44.5, 43. , 18.4, 40.6, 25.5, 47.8,  4.9, 33.5, 36.5, 14. ,
#        31.6, 21. , 42.3,  4.3, 36.3, 10.1, 17.2, 34.3, 46.4, 11. ,  0.3,
#         0.4, 26.9,  8.2, 38. , 15.4, 20.6, 46.8, 35. ,  0.8, 36.9, 26.8,
#        21.7,  2.4, 34.6, 32.3, 11.8, 38.9,  0. , 49. , 12. ,  2.9, 27.2,
#        38.6, 47. , 39. , 28.9, 25.9, 17. , 35.4, 33.2, 14.8,  1.9,  7.3,
#        40.3, 25.8, 13.9, 23.3, 39.7, 21.1, 11.6, 43.5,  1.3, 18.1, 35.8,
# ...

# %%
df['sales'].unique()
# Out:
# array([22.1, 10.4,  9.3, 18.5, 12.9,  7.2, 11.8, 13.2,  4.8, 10.6,  8.6,
#        17.4,  9.2,  9.7, 19. , 22.4, 12.5, 24.4, 11.3, 14.6, 18. ,  5.6,
#        15.5, 12. , 15. , 15.9, 18.9, 10.5, 21.4, 11.9,  9.6,  9.5, 12.8,
#        25.4, 14.7, 10.1, 21.5, 16.6, 17.1, 20.7,  8.5, 14.9, 23.2, 14.8,
#        11.4, 10.7, 22.6, 21.2, 20.2, 23.7,  5.5, 23.8, 18.4,  8.1, 24.2,
#        15.7, 14. , 13.4, 22.3, 18.3, 12.4,  8.8, 11. , 17. ,  8.7,  6.9,
#        14.2,  5.3, 12.3, 13.6, 21.7, 15.2, 16. , 16.7, 11.2,  7.3, 19.4,
#        22.2, 11.5, 16.9, 11.7, 17.2, 19.2, 19.8, 21.8, 14.1, 12.6, 12.2,
#         9.4,  6.6,  7. , 11.6, 19.7, 24.7,  1.6, 12.7,  5.7, 19.6, 10.8,
#        20.8, 10.9, 20.1, 10.3, 16.1, 15.6,  3.2, 15.3, 14.4, 13.3,  8. ,
#         8.4, 14.5,  7.6, 27. , 26.2, 17.6, 17.3,  6.7,  9.9,  5.9, 25.5])

# %%
## handling duplicate values first lets see how many null values are there
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
stand=pd.DataFrame(StandardScaler().fit_transform(df))
stand
# Out:
#             0         1         2         3         4
# 0   -1.723412  0.969852  0.981522  1.778945  1.552053
# 1   -1.706091 -1.197376  1.082808  0.669579 -0.696046
# 2   -1.688771 -1.516155  1.528463  1.783549 -0.907406
# 3   -1.671450  0.052050  1.217855  1.286405  0.860330
# 4   -1.654129  0.394182 -0.841614  1.281802 -0.215683
# ..        ...       ...       ...       ...       ...
# 195  1.654129 -1.270941 -1.321031 -0.771217 -1.234053
# 196  1.671450 -0.617035 -1.240003 -1.033598 -0.830548
# 197  1.688771  0.349810 -0.942899 -1.111852 -0.234898
# 198  1.706091  1.594565  1.265121  1.640850  2.205347
# 199  1.723412  0.993206 -0.990165 -1.005979 -0.119610
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
df['TV'].duplicated().any()
df['radio'].duplicated().any()
df['newspaper'].duplicated().any()
df['sales'].duplicated().any()
# Out:
# True

# %%
df['TV'].drop_duplicates()
# Out:
# 0      230.1
# 1       44.5
# 2       17.2
# 3      151.5
# 4      180.8
#        ...
# 194    149.7
# 195     38.2
# 196     94.2
# 198    283.6
# 199    232.1
# Name: TV, Length: 190, dtype: float64

# %%
df['radio'].drop_duplicates()
# Out:
# 0      37.8
# 1      39.3
# 2      45.9
# 3      41.3
# 4      10.8
#        ...
# 190    41.1
# 193    42.0
# 194    35.6
# 195     3.7
# 199     8.6
# Name: radio, Length: 167, dtype: float64

# %%
df['newspaper'].drop_duplicates()
# Out:
# 0      69.2
# 1      45.1
# 2      69.3
# 3      58.5
# 4      58.4
#        ...
# 190     5.8
# 191     6.0
# 195    13.8
# 196     8.1
# 198    66.2
# Name: newspaper, Length: 172, dtype: float64

# %%
df['sales'].drop_duplicates()
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 187    17.3
# 189     6.7
# 191     9.9
# 192     5.9
# 198    25.5
# Name: sales, Length: 121, dtype: float64

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Standardise the data set by using different scalling methods

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import Normalizer
s=StandardScaler()
m=MinMaxScaler()
r=RobustScaler()
n=Normalizer()

# %%
s1=s.fit_transform(df) 
m1=m.fit_transform(df)
r1=r.fit_transform(df)
n1=n.fit_transform(df)

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(df)
plt.title("~Before scaling~")
plt.show()

# %%
plt.boxplot(s1)
plt.title(" ~Standard  scaling~")
plt.show()

# %%
plt.boxplot(m1)
plt.title(" ~Minmax  scaling~")
plt.show()

# %%
plt.boxplot(r1)
plt.title("~Robust  scaling~")
plt.show()

# %%
plt.boxplot(n1)
plt.title("~Normalizer  scaling~")
plt.show()

# %% [markdown]
# ## plot

# %%
import numpy as np
plt.figure(figsize = (25, 10))

df1 = df.head(10)


plt.plot(df1['TV'], df1['sales'],df1['radio'],df1['newspaper'])
plt.show()

# %%
x=df['TV']
y=df['sales']
plt.scatter(x, y)

# %%
x=df['radio']
y=df['newspaper']
plt.scatter(x, y)

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df['sales'].value_counts().head(10).plot.pie()
# Out:
# <AxesSubplot:ylabel='sales'>

# %%
plt.hist(df1)
# Out:
# (array([[10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [ 3.,  1.,  1.,  0.,  0.,  1.,  1.,  1.,  1.,  1.],
#         [ 4.,  5.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [ 4.,  1.,  4.,  1.,  0.,  0.,  0.,  0.,  0.,  0.],
#         [10.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]]),
#  array([  1.  ,  23.91,  46.82,  69.73,  92.64, 115.55, 138.46, 161.37,
#         184.28, 207.19, 230.1 ]),
#  <a list of 5 BarContainer objects>)

# %%
plt.boxplot(df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18d37719b08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18d37719408>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18d37a90408>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x18d37719c48>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x18d37719908>,
# ...
#  'means': []}

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.2; however, version 21.1.3 is available.
# You should consider upgrading via the 'c:\users\prave\appdata\local\programs\python\python37\python.exe -m pip install --upgrade pip' command.

# %%
plt.scatter(df.newspaper,df.sales)
plt.title('NEWSPAPER-SALES')
plt.xlabel('newspaper')
plt.ylabel('sales')
plt.show()

# %%
plt.scatter(df.TV,df.sales)
plt.title('TV-SALES')
plt.xlabel('TV')
plt.ylabel('sales')
plt.show()

# %%
plt.scatter(df.TV,df.sales,label='TV')
plt.scatter(df.radio,df.sales,label='radio')
plt.scatter(df.newspaper,df.sales,label='newspaper')
plt.legend()

# %%
sns.distplot(df['sales'])
# Out:
# c:\users\prave\appdata\local\programs\python\python37\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %%
sns.histplot(df['sales'] , kde=True)
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Count'>

# %%
sns.pairplot(df , diag_kind='kde')
